# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import lxml

# %%
# source=requests.get(url=input('Enter the url of the tournament \n')).text

match_url_list = []

source_matchlist = requests.get(url='https://www.vlr.gg/event/matches/800/champions-tour-north-america-stage-2-challengers/?series_id=1903').text

soup_matchlist = BeautifulSoup(source_matchlist,'lxml')

days = soup_matchlist.findAll('div', {'class':'wf-card'})

for d in range(1,len(days)):
    for i in days[d].findAll(href=True):
        match_url_list.append(i['href'])

# %%
days
# Out:
# [<div class="wf-card mod-event mod-header mod-full" style="z-index: 3;">
#  <div class="event-header">
#  <div class="wf-avatar event-header-thumb">
#  <div>
#  <img alt="Champions Tour North America Stage 2: Challengers" src="//owcdn.net/img/6009f963577f4.png"/>
#  </div>
#  </div>
#  <div class="event-desc">
#  <div class="event-desc-inner">
#  <div style="display: flex; align-items: center; margin-bottom: 2px;">
#  <i class="fa fa-tag" style="font-size: 14px; margin-right: 5px;"></i>
#  <a href="/vct">Valorant Champions Tour 2022</a>
#  <div style="margin: 0 5px;">⋅</div>
#  <a href="/vct/?stage=53">Stage 2</a>
#  <div style="margin: 0 5px;">⋅</div>
#  <a href="/vct/?region=52">North America</a>
#  </div>
#  <h1 class="wf-title" style="display: inline;">
#  					Champions Tour North America Stage 2: Challengers				</h1>
#  <h2 class="event-desc-subtitle">
#  					Part of the Valorant Champions Tour, Riot's official 2022 tournament circuit				</h2>
#  <div class="event-desc-items">
#  <div class="event-desc-item">
#  <div class="ge-text-light event-desc-item-label">
#  							Dates
#  						</div>
#  <div class="event-desc-item-value">
#  							Apr 28, 2022 - Jun 26, 2022						</div>
#  </div>
#  <div class="event-desc-item">
#  <div class="ge-text-light event-desc-item-label">
#  							Prize pool
#  						</div>
#  <div class="event-desc-item-value">
#  							$200,000 USD													</div>
#  </div>
#  <div class="event-desc-item mod-last">
#  <div class="ge-text-light event-desc-item-label">
#  															Region
#  													</div>
#  <div class="event-desc-item-value" style="margin-top: -2px;">
#  <i class="flag mod-us" style="vertical-align: -4px; margin-right: 4px;"></i>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="wf-nav" style="z-index: 3;">
#  <a class="wf-nav-item mod-first mod-hassubnav" href="/event/800/champions-tour-north-america-stage-2-challengers">
#  <div class="wf-nav-item-title">
#  				Overview
#  			</div>
#  </a>
#  <!--
#  		<a class="wf-nav-item ">
#  			<div class="wf-nav-item-title">
#  				Teams
#  			</div>
#  		</a>
#  		-->
#  <a class="wf-nav-item mod-active" href="/event/matches/800/champions-tour-north-america-stage-2-challengers/?series_id=1903">
#  <div class="wf-nav-item-title">
#  				Matches (290)
#  			</div>
#  </a>
#  <a class="wf-nav-item" href="/event/pickem/800/champions-tour-north-america-stage-2-challengers">
#  <div class="wf-nav-item-title">
#  					Pick'em
#  				</div>
#  </a>
#  <a class="wf-nav-item" href="/event/stats/800/champions-tour-north-america-stage-2-challengers">
#  <div class="wf-nav-item-title">
#  					Stats
#  				</div>
#  </a>
#  <a class="wf-nav-item" href="/event/agents/800/champions-tour-north-america-stage-2-challengers">
#  <div class="wf-nav-item-title">
#  					Agents
#  				</div>
#  </a>
#  <a class="wf-nav-item" href="/event/news/800/champions-tour-north-america-stage-2-challengers">
#  <div class="wf-nav-item-title">
#  					News (2)
#  				</div>
#  </a>
#  </div>
#  </div>,
#  <div class="wf-card" style="margin-bottom: 30px;">
#  <a class="wf-module-item match-item mod-color mod-left mod-bg-after-red mod-first" href="/96983/gorilla-gang-vs-phoenix2-champions-tour-north-america-stage-2-challengers-ro128">
#  <div class="match-item-time">
#  													6:00 PM											</div>
#  <div class="match-item-vs">
#  <div class="match-item-vs-team mod-winner">
#  <div class="match-item-vs-team-name">
#  <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Gorilla Gang										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					2																			</div>
#  </div>
#  <div class="match-item-vs-team">
#  <div class="match-item-vs-team-name">
#  <div class="text-of">
#  <span class="flag mod-un"></span>
#  											Phoenix2										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					0																			</div>
#  </div>
#  </div>
#  <div class="match-item-eta">
#  <div class="ml mod-completed">
#  <div class="ml-status">Completed</div>
#  <div class="ml-eta mod-completed">6d 22h</div>
#  </div>
#  </div>
#  <div class="match-item-note">
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							Stats:
#  						</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Map
#  								</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Player
#  								</div>
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							VODs:
#  						</div>
#
#
#
#
#  														Unavailable
#
#  											</div>
#  <div class="match-item-event text-of">
#  <div class="match-item-event-series text-of">
#  								Round of 128							</div>
#  							Open Qualifier #2											</div>
#  </a>
#  <a class="wf-module-item match-item mod-color mod-left mod-bg-after-red" href="/96984/team-reckaroo-vs-gen-g-black-champions-tour-north-america-stage-2-challengers-ro128">
#  <div class="match-item-time">
#  													6:00 PM											</div>
#  <div class="match-item-vs">
#  <div class="match-item-vs-team mod-winner">
#  <div class="match-item-vs-team-name">
#  <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Team Reckaroo										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					2																			</div>
#  </div>
#  <div class="match-item-vs-team">
#  <div class="match-item-vs-team-name">
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Gen.G Black										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					0																			</div>
#  </div>
#  </div>
#  <div class="match-item-eta">
#  <div class="ml mod-completed">
#  <div class="ml-status">Completed</div>
#  <div class="ml-eta mod-completed">6d 22h</div>
#  </div>
#  </div>
#  <div class="match-item-note">
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							Stats:
#  						</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Map
#  								</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Player
#  								</div>
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							VODs:
#  						</div>
#
#
#
#
#  														Unavailable
#
#  											</div>
#  <div class="match-item-event text-of">
#  <div class="match-item-event-series text-of">
#  								Round of 128							</div>
#  							Open Qualifier #2											</div>
#  </a>
#  <a class="wf-module-item match-item mod-color mod-left mod-bg-after-red" href="/96985/t1-vs-misfits-black-champions-tour-north-america-stage-2-challengers-ro128">
#  <div class="match-item-time">
#  													6:00 PM											</div>
#  <div class="match-item-vs">
#  <div class="match-item-vs-team mod-winner">
#  <div class="match-item-vs-team-name">
#  <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											T1										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					2																			</div>
#  </div>
#  <div class="match-item-vs-team">
#  <div class="match-item-vs-team-name">
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Misfits Black										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					0																			</div>
#  </div>
#  </div>
#  <div class="match-item-eta">
#  <div class="ml mod-completed">
#  <div class="ml-status">Completed</div>
#  <div class="ml-eta mod-completed">6d 22h</div>
#  </div>
#  </div>
#  <div class="match-item-note">
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							Stats:
#  						</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Map
#  								</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Player
#  								</div>
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							VODs:
#  						</div>
#
#
#
#
#  														Unavailable
#
#  											</div>
#  <div class="match-item-event text-of">
#  <div class="match-item-event-series text-of">
#  								Round of 128							</div>
#  							Open Qualifier #2											</div>
#  </a>
#  <a class="wf-module-item match-item mod-color mod-left mod-bg-after-red" href="/96986/aftermath-esports-vs-team-opulence-gold-champions-tour-north-america-stage-2-challengers-ro128">
#  <div class="match-item-time">
#  													6:00 PM											</div>
#  <div class="match-item-vs">
#  <div class="match-item-vs-team mod-winner">
#  <div class="match-item-vs-team-name">
#  <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
#  <div class="text-of">
#  <span class="flag mod-ca"></span>
#  											afterMath Esports										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					2																			</div>
#  </div>
#  <div class="match-item-vs-team">
#  <div class="match-item-vs-team-name">
#  <div class="text-of">
#  <span class="flag mod-un"></span>
#  											Team Opulence Gold										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					0																			</div>
#  </div>
#  </div>
#  <div class="match-item-eta">
#  <div class="ml mod-completed">
#  <div class="ml-status">Completed</div>
#  <div class="ml-eta mod-completed">6d 22h</div>
#  </div>
#  </div>
#  <div class="match-item-note">
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							Stats:
#  						</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Map
#  								</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Player
#  								</div>
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							VODs:
#  						</div>
#
#
#
#
#  														Unavailable
#
#  											</div>
#  <div class="match-item-event text-of">
#  <div class="match-item-event-series text-of">
#  								Round of 128							</div>
#  							Open Qualifier #2											</div>
#  </a>
#  <a class="wf-module-item match-item mod-color mod-left mod-bg-after-red" href="/96987/soniqs-vs-1rule-champions-tour-north-america-stage-2-challengers-ro128">
#  <div class="match-item-time">
#  													6:00 PM											</div>
#  <div class="match-item-vs">
#  <div class="match-item-vs-team mod-winner">
#  <div class="match-item-vs-team-name">
#  <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
#  <div class="text-of">
#  <span class="flag mod-au"></span>
#  											Soniqs										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					2																			</div>
#  </div>
#  <div class="match-item-vs-team">
#  <div class="match-item-vs-team-name">
#  <div class="text-of">
#  <span class="flag mod-un"></span>
#  											1Rule										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					0																			</div>
#  </div>
#  </div>
#  <div class="match-item-eta">
#  <div class="ml mod-completed">
#  <div class="ml-status">Completed</div>
#  <div class="ml-eta mod-completed">6d 22h</div>
#  </div>
#  </div>
#  <div class="match-item-note">
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							Stats:
#  						</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Map
#  								</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Player
#  								</div>
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							VODs:
#  						</div>
#
#
#
#
#  														Unavailable
#
#  											</div>
#  <div class="match-item-event text-of">
#  <div class="match-item-event-series text-of">
#  								Round of 128							</div>
#  							Open Qualifier #2											</div>
#  </a>
#  <a class="wf-module-item match-item mod-color mod-left mod-bg-after-red" href="/96988/vexo-esports-vs-select-few-champions-tour-north-america-stage-2-challengers-ro128">
#  <div class="match-item-time">
#  													6:00 PM											</div>
#  <div class="match-item-vs">
#  <div class="match-item-vs-team mod-winner">
#  <div class="match-item-vs-team-name">
#  <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
#  <div class="text-of">
#  <span class="flag mod-ca"></span>
#  											Vexo Esports										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					2																			</div>
#  </div>
#  <div class="match-item-vs-team">
#  <div class="match-item-vs-team-name">
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											select few										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					0																			</div>
#  </div>
#  </div>
#  <div class="match-item-eta">
#  <div class="ml mod-completed">
#  <div class="ml-status">Completed</div>
#  <div class="ml-eta mod-completed">6d 22h</div>
#  </div>
#  </div>
#  <div class="match-item-note">
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							Stats:
#  						</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Map
#  								</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Player
#  								</div>
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							VODs:
#  						</div>
#
#
#
#
#  														Unavailable
#
#  											</div>
#  <div class="match-item-event text-of">
#  <div class="match-item-event-series text-of">
#  								Round of 128							</div>
#  							Open Qualifier #2											</div>
#  </a>
#  <a class="wf-module-item match-item mod-color mod-left mod-bg-after-red" href="/96991/lenny-time-vs-eros-champions-tour-north-america-stage-2-challengers-ro128">
#  <div class="match-item-time">
#  													6:00 PM											</div>
#  <div class="match-item-vs">
#  <div class="match-item-vs-team mod-winner">
#  <div class="match-item-vs-team-name">
#  <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Lenny Time										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					2																			</div>
#  </div>
#  <div class="match-item-vs-team">
#  <div class="match-item-vs-team-name">
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Eros										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					0																			</div>
#  </div>
#  </div>
#  <div class="match-item-eta">
#  <div class="ml mod-completed">
#  <div class="ml-status">Completed</div>
#  <div class="ml-eta mod-completed">6d 22h</div>
#  </div>
#  </div>
#  <div class="match-item-note">
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							Stats:
#  						</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Map
#  								</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Player
#  								</div>
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							VODs:
#  						</div>
#
#
#
#
#  														Unavailable
#
#  											</div>
#  <div class="match-item-event text-of">
#  <div class="match-item-event-series text-of">
#  								Round of 128							</div>
#  							Open Qualifier #2											</div>
#  </a>
#  <a class="wf-module-item match-item mod-color mod-left mod-bg-after-red" href="/96992/able-esports-vs-starbound-champions-tour-north-america-stage-2-challengers-ro128">
#  <div class="match-item-time">
#  													6:00 PM											</div>
#  <div class="match-item-vs">
#  <div class="match-item-vs-team">
#  <div class="match-item-vs-team-name">
#  <div class="text-of">
#  <span class="flag mod-ca"></span>
#  											Able Esports										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					1																			</div>
#  </div>
#  <div class="match-item-vs-team mod-winner">
#  <div class="match-item-vs-team-name">
#  <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
#  <div class="text-of">
#  <span class="flag mod-un"></span>
#  											StarBound										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					2																			</div>
#  </div>
#  </div>
#  <div class="match-item-eta">
#  <div class="ml mod-completed">
#  <div class="ml-status">Completed</div>
#  <div class="ml-eta mod-completed">6d 22h</div>
#  </div>
#  </div>
#  <div class="match-item-note">
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							Stats:
#  						</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Map
#  								</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Player
#  								</div>
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							VODs:
#  						</div>
#
#
#
#
#  														Unavailable
#
#  											</div>
#  <div class="match-item-event text-of">
#  <div class="match-item-event-series text-of">
#  								Round of 128							</div>
#  							Open Qualifier #2											</div>
#  </a>
#  <a class="wf-module-item match-item mod-color mod-left mod-bg-after-red" href="/96993/gen-g-vs-panda-party-champions-tour-north-america-stage-2-challengers-ro128">
#  <div class="match-item-time">
#  													6:00 PM											</div>
#  <div class="match-item-vs">
#  <div class="match-item-vs-team mod-winner">
#  <div class="match-item-vs-team-name">
#  <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Gen.G										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					2																			</div>
#  </div>
#  <div class="match-item-vs-team">
#  <div class="match-item-vs-team-name">
#  <div class="text-of">
#  <span class="flag mod-un"></span>
#  											Panda Party										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					0																			</div>
#  </div>
#  </div>
#  <div class="match-item-eta">
#  <div class="ml mod-completed">
#  <div class="ml-status">Completed</div>
#  <div class="ml-eta mod-completed">6d 22h</div>
#  </div>
#  </div>
#  <div class="match-item-note">
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							Stats:
#  						</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Map
#  								</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Player
#  								</div>
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							VODs:
#  						</div>
#
#
#
#
#  														Unavailable
#
#  											</div>
#  <div class="match-item-event text-of">
#  <div class="match-item-event-series text-of">
#  								Round of 128							</div>
#  							Open Qualifier #2											</div>
#  </a>
#  <a class="wf-module-item match-item mod-color mod-left mod-bg-after-red" href="/96994/spectral-esports-vs-big-baller-brand-champions-tour-north-america-stage-2-challengers-ro128">
#  <div class="match-item-time">
#  													6:00 PM											</div>
#  <div class="match-item-vs">
#  <div class="match-item-vs-team">
#  <div class="match-item-vs-team-name">
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Spectral Esports										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					0																			</div>
#  </div>
#  <div class="match-item-vs-team mod-winner">
#  <div class="match-item-vs-team-name">
#  <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Big Baller Brand										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					2																			</div>
#  </div>
#  </div>
#  <div class="match-item-eta">
#  <div class="ml mod-completed">
#  <div class="ml-status">Completed</div>
#  <div class="ml-eta mod-completed">6d 22h</div>
#  </div>
#  </div>
#  <div class="match-item-note">
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							Stats:
#  						</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Map
#  								</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Player
#  								</div>
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							VODs:
#  						</div>
#
#
#
#
#  														Unavailable
#
#  											</div>
#  <div class="match-item-event text-of">
#  <div class="match-item-event-series text-of">
#  								Round of 128							</div>
#  							Open Qualifier #2											</div>
#  </a>
#  <a class="wf-module-item match-item mod-color mod-left mod-bg-after-red" href="/96995/soar-vs-pasquallys-pizza-posse-champions-tour-north-america-stage-2-challengers-ro128">
#  <div class="match-item-time">
#  													6:00 PM											</div>
#  <div class="match-item-vs">
#  <div class="match-item-vs-team mod-winner">
#  <div class="match-item-vs-team-name">
#  <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											SoaR										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					2																			</div>
#  </div>
#  <div class="match-item-vs-team">
#  <div class="match-item-vs-team-name">
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Pasquallys Pizza Posse										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					0																			</div>
#  </div>
#  </div>
#  <div class="match-item-eta">
#  <div class="ml mod-completed">
#  <div class="ml-status">Completed</div>
#  <div class="ml-eta mod-completed">6d 22h</div>
#  </div>
#  </div>
#  <div class="match-item-note">
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							Stats:
#  						</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Map
#  								</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Player
#  								</div>
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							VODs:
#  						</div>
#
#
#
#
#  														Unavailable
#
#  											</div>
#  <div class="match-item-event text-of">
#  <div class="match-item-event-series text-of">
#  								Round of 128							</div>
#  							Open Qualifier #2											</div>
#  </a>
#  <a class="wf-module-item match-item mod-color mod-left mod-bg-after-red" href="/96996/tradelikepros-red-vs-pulsar-red-champions-tour-north-america-stage-2-challengers-ro128">
#  <div class="match-item-time">
#  													6:00 PM											</div>
#  <div class="match-item-vs">
#  <div class="match-item-vs-team mod-winner">
#  <div class="match-item-vs-team-name">
#  <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											TradeLikePros Red										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					2																			</div>
#  </div>
#  <div class="match-item-vs-team">
#  <div class="match-item-vs-team-name">
#  <div class="text-of">
#  <span class="flag mod-un"></span>
#  											Pulsar Red										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					0																			</div>
#  </div>
#  </div>
#  <div class="match-item-eta">
#  <div class="ml mod-completed">
#  <div class="ml-status">Completed</div>
#  <div class="ml-eta mod-completed">6d 22h</div>
#  </div>
#  </div>
#  <div class="match-item-note">
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							Stats:
#  						</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Map
#  								</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Player
#  								</div>
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							VODs:
#  						</div>
#
#
#
#
#  														Unavailable
#
#  											</div>
#  <div class="match-item-event text-of">
#  <div class="match-item-event-series text-of">
#  								Round of 128							</div>
#  							Open Qualifier #2											</div>
#  </a>
#  <a class="wf-module-item match-item mod-color mod-left mod-bg-after-red" href="/96999/clanless-vs-slodi-repus-champions-tour-north-america-stage-2-challengers-ro128">
#  <div class="match-item-time">
#  													6:00 PM											</div>
#  <div class="match-item-vs">
#  <div class="match-item-vs-team mod-winner">
#  <div class="match-item-vs-team-name">
#  <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
#  <div class="text-of">
#  <span class="flag mod-ca"></span>
#  											Clanless										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					2																			</div>
#  </div>
#  <div class="match-item-vs-team">
#  <div class="match-item-vs-team-name">
#  <div class="text-of">
#  <span class="flag mod-un"></span>
#  											SLODI REPUS										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					0																			</div>
#  </div>
#  </div>
#  <div class="match-item-eta">
#  <div class="ml mod-completed">
#  <div class="ml-status">Completed</div>
#  <div class="ml-eta mod-completed">6d 22h</div>
#  </div>
#  </div>
#  <div class="match-item-note">
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							Stats:
#  						</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Map
#  								</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Player
#  								</div>
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							VODs:
#  						</div>
#
#
#
#
#  														Unavailable
#
#  											</div>
#  <div class="match-item-event text-of">
#  <div class="match-item-event-series text-of">
#  								Round of 128							</div>
#  							Open Qualifier #2											</div>
#  </a>
#  <a class="wf-module-item match-item mod-color mod-left mod-bg-after-red" href="/97000/resonate-vs-gonjo-champions-tour-north-america-stage-2-challengers-ro128">
#  <div class="match-item-time">
#  													6:00 PM											</div>
#  <div class="match-item-vs">
#  <div class="match-item-vs-team mod-winner">
#  <div class="match-item-vs-team-name">
#  <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Resonate										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					2																			</div>
#  </div>
#  <div class="match-item-vs-team">
#  <div class="match-item-vs-team-name">
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											GONJO										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					1																			</div>
#  </div>
#  </div>
#  <div class="match-item-eta">
#  <div class="ml mod-completed">
#  <div class="ml-status">Completed</div>
#  <div class="ml-eta mod-completed">6d 22h</div>
#  </div>
#  </div>
#  <div class="match-item-note">
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							Stats:
#  						</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Map
#  								</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Player
#  								</div>
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							VODs:
#  						</div>
#
#
#
#
#  														Unavailable
#
#  											</div>
#  <div class="match-item-event text-of">
#  <div class="match-item-event-series text-of">
#  								Round of 128							</div>
#  							Open Qualifier #2											</div>
#  </a>
#  <a class="wf-module-item match-item mod-color mod-left mod-bg-after-red" href="/97001/akrew-vs-ugly-hamsters-champions-tour-north-america-stage-2-challengers-ro128">
#  <div class="match-item-time">
#  													6:00 PM											</div>
#  <div class="match-item-vs">
#  <div class="match-item-vs-team mod-winner">
#  <div class="match-item-vs-team-name">
#  <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Akrew										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					0																			</div>
#  </div>
#  <div class="match-item-vs-team">
#  <div class="match-item-vs-team-name">
#  <div class="text-of">
#  <span class="flag mod-un"></span>
#  											Ugly Hamsters										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					0																			</div>
#  </div>
#  </div>
#  <div class="match-item-eta">
#  <div class="ml mod-completed">
#  <div class="ml-status">Completed</div>
#  <div class="ml-eta mod-completed">6d 22h</div>
#  </div>
#  </div>
#  <div class="match-item-note">
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							Stats:
#  						</div>
#
#
#  															Unavailable
#
#
#
#
#  											</div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							VODs:
#  						</div>
#
#
#
#
#  														Unavailable
#
#  											</div>
#  <div class="match-item-event text-of">
#  <div class="match-item-event-series text-of">
#  								Round of 128							</div>
#  							Open Qualifier #2											</div>
#  </a>
#  <a class="wf-module-item match-item mod-color mod-left mod-bg-after-red" href="/97002/nation-gaming-vs-baddiesonval-champions-tour-north-america-stage-2-challengers-ro128">
#  <div class="match-item-time">
#  													6:00 PM											</div>
#  <div class="match-item-vs">
#  <div class="match-item-vs-team mod-winner">
#  <div class="match-item-vs-team-name">
#  <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Nation Gaming										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					2																			</div>
#  </div>
#  <div class="match-item-vs-team">
#  <div class="match-item-vs-team-name">
#  <div class="text-of">
#  <span class="flag mod-un"></span>
#  											BaddiesOnVal										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					0																			</div>
#  </div>
#  </div>
#  <div class="match-item-eta">
#  <div class="ml mod-completed">
#  <div class="ml-status">Completed</div>
#  <div class="ml-eta mod-completed">6d 22h</div>
#  </div>
#  </div>
#  <div class="match-item-note">
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							Stats:
#  						</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Map
#  								</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Player
#  								</div>
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							VODs:
#  						</div>
#
#
#
#
#  														Unavailable
#
#  											</div>
#  <div class="match-item-event text-of">
#  <div class="match-item-event-series text-of">
#  								Round of 128							</div>
#  							Open Qualifier #2											</div>
#  </a>
#  <a class="wf-module-item match-item mod-color mod-left mod-bg-after-red" href="/97003/team-basilisk-vs-5-of-a-kind-champions-tour-north-america-stage-2-challengers-ro128">
#  <div class="match-item-time">
#  													6:00 PM											</div>
#  <div class="match-item-vs">
#  <div class="match-item-vs-team mod-winner">
#  <div class="match-item-vs-team-name">
#  <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Team Basilisk										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					2																			</div>
#  </div>
#  <div class="match-item-vs-team">
#  <div class="match-item-vs-team-name">
#  <div class="text-of">
#  <span class="flag mod-ca"></span>
#  											5 of a Kind										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					0																			</div>
#  </div>
#  </div>
#  <div class="match-item-eta">
#  <div class="ml mod-completed">
#  <div class="ml-status">Completed</div>
#  <div class="ml-eta mod-completed">6d 22h</div>
#  </div>
#  </div>
#  <div class="match-item-note">
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							Stats:
#  						</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Map
#  								</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Player
#  								</div>
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							VODs:
#  						</div>
#
#
#
#
#  														Unavailable
#
#  											</div>
#  <div class="match-item-event text-of">
#  <div class="match-item-event-series text-of">
#  								Round of 128							</div>
#  							Open Qualifier #2											</div>
#  </a>
#  <a class="wf-module-item match-item mod-color mod-left mod-bg-after-red" href="/97004/hypehorizen-vs-zenigma-alpha-champions-tour-north-america-stage-2-challengers-ro128">
#  <div class="match-item-time">
#  													6:00 PM											</div>
#  <div class="match-item-vs">
#  <div class="match-item-vs-team mod-winner">
#  <div class="match-item-vs-team-name">
#  <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											HypeHorizen										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					2																			</div>
#  </div>
#  <div class="match-item-vs-team">
#  <div class="match-item-vs-team-name">
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Zenigma Alpha										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					1																			</div>
#  </div>
#  </div>
#  <div class="match-item-eta">
#  <div class="ml mod-completed">
#  <div class="ml-status">Completed</div>
#  <div class="ml-eta mod-completed">6d 22h</div>
#  </div>
#  </div>
#  <div class="match-item-note">
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							Stats:
#  						</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Map
#  								</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Player
#  								</div>
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							VODs:
#  						</div>
#
#
#
#
#  														Unavailable
#
#  											</div>
#  <div class="match-item-event text-of">
#  <div class="match-item-event-series text-of">
#  								Round of 128							</div>
#  							Open Qualifier #2											</div>
#  </a>
#  <a class="wf-module-item match-item mod-color mod-left mod-bg-after-red" href="/97007/nights-academy-vs-mew2-champions-tour-north-america-stage-2-challengers-ro128">
#  <div class="match-item-time">
#  													6:00 PM											</div>
#  <div class="match-item-vs">
#  <div class="match-item-vs-team mod-winner">
#  <div class="match-item-vs-team-name">
#  <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Nights Academy										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					2																			</div>
#  </div>
#  <div class="match-item-vs-team">
#  <div class="match-item-vs-team-name">
#  <div class="text-of">
#  <span class="flag mod-un"></span>
#  											MEW2										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					0																			</div>
#  </div>
#  </div>
#  <div class="match-item-eta">
#  <div class="ml mod-completed">
#  <div class="ml-status">Completed</div>
#  <div class="ml-eta mod-completed">6d 22h</div>
#  </div>
#  </div>
#  <div class="match-item-note">
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							Stats:
#  						</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Map
#  								</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Player
#  								</div>
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							VODs:
#  						</div>
#
#
#
#
#  														Unavailable
#
#  											</div>
#  <div class="match-item-event text-of">
#  <div class="match-item-event-series text-of">
#  								Round of 128							</div>
#  							Open Qualifier #2											</div>
#  </a>
#  <a class="wf-module-item match-item mod-color mod-left mod-bg-after-red" href="/97008/unknown-vs-based-champions-tour-north-america-stage-2-challengers-ro128">
#  <div class="match-item-time">
#  													6:00 PM											</div>
#  <div class="match-item-vs">
#  <div class="match-item-vs-team">
#  <div class="match-item-vs-team-name">
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Unknown										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					0																			</div>
#  </div>
#  <div class="match-item-vs-team mod-winner">
#  <div class="match-item-vs-team-name">
#  <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
#  <div class="text-of">
#  <span class="flag mod-un"></span>
#  											BASED										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					2																			</div>
#  </div>
#  </div>
#  <div class="match-item-eta">
#  <div class="ml mod-completed">
#  <div class="ml-status">Completed</div>
#  <div class="ml-eta mod-completed">6d 22h</div>
#  </div>
#  </div>
#  <div class="match-item-note">
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							Stats:
#  						</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Map
#  								</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Player
#  								</div>
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							VODs:
#  						</div>
#
#
#
#
#  														Unavailable
#
#  											</div>
#  <div class="match-item-event text-of">
#  <div class="match-item-event-series text-of">
#  								Round of 128							</div>
#  							Open Qualifier #2											</div>
#  </a>
#  <a class="wf-module-item match-item mod-color mod-left mod-bg-after-red" href="/97009/complexity-vs-nanas-biscuits-champions-tour-north-america-stage-2-challengers-ro128">
#  <div class="match-item-time">
#  													6:00 PM											</div>
#  <div class="match-item-vs">
#  <div class="match-item-vs-team mod-winner">
#  <div class="match-item-vs-team-name">
#  <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Complexity										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					2																			</div>
#  </div>
#  <div class="match-item-vs-team">
#  <div class="match-item-vs-team-name">
#  <div class="text-of">
#  <span class="flag mod-un"></span>
#  											Nana's Biscuits										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					0																			</div>
#  </div>
#  </div>
#  <div class="match-item-eta">
#  <div class="ml mod-completed">
#  <div class="ml-status">Completed</div>
#  <div class="ml-eta mod-completed">6d 22h</div>
#  </div>
#  </div>
#  <div class="match-item-note">
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							Stats:
#  						</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Map
#  								</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Player
#  								</div>
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							VODs:
#  						</div>
#
#
#
#
#  														Unavailable
#
#  											</div>
#  <div class="match-item-event text-of">
#  <div class="match-item-event-series text-of">
#  								Round of 128							</div>
#  							Open Qualifier #2											</div>
#  </a>
#  <a class="wf-module-item match-item mod-color mod-left mod-bg-after-red" href="/97010/free-fall-vs-omnipotent-gaming-champions-tour-north-america-stage-2-challengers-ro128">
#  <div class="match-item-time">
#  													6:00 PM											</div>
#  <div class="match-item-vs">
#  <div class="match-item-vs-team mod-winner">
#  <div class="match-item-vs-team-name">
#  <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Free Fall										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					2																			</div>
#  </div>
#  <div class="match-item-vs-team">
#  <div class="match-item-vs-team-name">
#  <div class="text-of">
#  <span class="flag mod-un"></span>
#  											Omnipotent Gaming										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					0																			</div>
#  </div>
#  </div>
#  <div class="match-item-eta">
#  <div class="ml mod-completed">
#  <div class="ml-status">Completed</div>
#  <div class="ml-eta mod-completed">6d 22h</div>
#  </div>
#  </div>
#  <div class="match-item-note">
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							Stats:
#  						</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Map
#  								</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Player
#  								</div>
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							VODs:
#  						</div>
#
#
#
#
#  														Unavailable
#
#  											</div>
#  <div class="match-item-event text-of">
#  <div class="match-item-event-series text-of">
#  								Round of 128							</div>
#  							Open Qualifier #2											</div>
#  </a>
#  <a class="wf-module-item match-item mod-color mod-left mod-bg-after-red" href="/97011/cosmic-divide-vs-chapter-4-champions-tour-north-america-stage-2-challengers-ro128">
#  <div class="match-item-time">
#  													6:00 PM											</div>
#  <div class="match-item-vs">
#  <div class="match-item-vs-team mod-winner">
#  <div class="match-item-vs-team-name">
#  <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Cosmic Divide										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					2																			</div>
#  </div>
#  <div class="match-item-vs-team">
#  <div class="match-item-vs-team-name">
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Chapter 4										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					0																			</div>
#  </div>
#  </div>
#  <div class="match-item-eta">
#  <div class="ml mod-completed">
#  <div class="ml-status">Completed</div>
#  <div class="ml-eta mod-completed">6d 22h</div>
#  </div>
#  </div>
#  <div class="match-item-note">
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							Stats:
#  						</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Map
#  								</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Player
#  								</div>
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							VODs:
#  						</div>
#
#
#
#
#  														Unavailable
#
#  											</div>
#  <div class="match-item-event text-of">
#  <div class="match-item-event-series text-of">
#  								Round of 128							</div>
#  							Open Qualifier #2											</div>
#  </a>
#  <a class="wf-module-item match-item mod-color mod-left mod-bg-after-red" href="/97012/lycus-empire-vs-conquest-esports-champions-tour-north-america-stage-2-challengers-ro128">
#  <div class="match-item-time">
#  													6:00 PM											</div>
#  <div class="match-item-vs">
#  <div class="match-item-vs-team mod-winner">
#  <div class="match-item-vs-team-name">
#  <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Lycus Empire										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					2																			</div>
#  </div>
#  <div class="match-item-vs-team">
#  <div class="match-item-vs-team-name">
#  <div class="text-of">
#  <span class="flag mod-un"></span>
#  											Conquest Esports										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					0																			</div>
#  </div>
#  </div>
#  <div class="match-item-eta">
#  <div class="ml mod-completed">
#  <div class="ml-status">Completed</div>
#  <div class="ml-eta mod-completed">6d 22h</div>
#  </div>
#  </div>
#  <div class="match-item-note">
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							Stats:
#  						</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Map
#  								</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Player
#  								</div>
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							VODs:
#  						</div>
#
#
#
#
#  														Unavailable
#
#  											</div>
#  <div class="match-item-event text-of">
#  <div class="match-item-event-series text-of">
#  								Round of 128							</div>
#  							Open Qualifier #2											</div>
#  </a>
#  <a class="wf-module-item match-item mod-color mod-left mod-bg-after-red" href="/97015/skwirel-warriers-vs-shift-walkers-champions-tour-north-america-stage-2-challengers-ro128">
#  <div class="match-item-time">
#  													6:00 PM											</div>
#  <div class="match-item-vs">
#  <div class="match-item-vs-team mod-winner">
#  <div class="match-item-vs-team-name">
#  <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Skwirel Warriers										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					2																			</div>
#  </div>
#  <div class="match-item-vs-team">
#  <div class="match-item-vs-team-name">
#  <div class="text-of">
#  <span class="flag mod-un"></span>
#  											Shift Walkers										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					0																			</div>
#  </div>
#  </div>
#  <div class="match-item-eta">
#  <div class="ml mod-completed">
#  <div class="ml-status">Completed</div>
#  <div class="ml-eta mod-completed">6d 22h</div>
#  </div>
#  </div>
# ...
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Built By Gamers Academy										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					2																			</div>
#  </div>
#  <div class="match-item-vs-team">
#  <div class="match-item-vs-team-name">
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Gen.G										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					0																			</div>
#  </div>
#  </div>
#  <div class="match-item-eta">
#  <div class="ml mod-completed">
#  <div class="ml-status">Completed</div>
#  <div class="ml-eta mod-completed">4d 21h</div>
#  </div>
#  </div>
#  <div class="match-item-note">
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							Stats:
#  						</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Map
#  								</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Player
#  								</div>
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							VODs:
#  						</div>
#
#
#
#
#  														Unavailable
#
#  											</div>
#  <div class="match-item-event text-of">
#  <div class="match-item-event-series text-of">
#  								Lower Round 4							</div>
#  							Open Qualifier #2											</div>
#  </a>
#  <a class="wf-module-item match-item mod-color mod-left mod-bg-after-red" href="/97205/evil-geniuses-vs-knights-champions-tour-north-america-stage-2-challengers-ubsf">
#  <div class="match-item-time">
#  													7:35 PM											</div>
#  <div class="match-item-vs">
#  <div class="match-item-vs-team mod-winner">
#  <div class="match-item-vs-team-name">
#  <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Evil Geniuses										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					2																			</div>
#  </div>
#  <div class="match-item-vs-team">
#  <div class="match-item-vs-team-name">
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Knights										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					0																			</div>
#  </div>
#  </div>
#  <div class="match-item-eta">
#  <div class="ml mod-completed">
#  <div class="ml-status">Completed</div>
#  <div class="ml-eta mod-completed">4d 21h</div>
#  </div>
#  </div>
#  <div class="match-item-note">
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							Stats:
#  						</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Map
#  								</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Player
#  								</div>
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							VODs:
#  						</div>
#
#
#
#
#  														Unavailable
#
#  											</div>
#  <div class="match-item-event text-of">
#  <div class="match-item-event-series text-of">
#  								Upper Semifinals							</div>
#  							Open Qualifier #2											</div>
#  </a>
#  <a class="wf-module-item match-item mod-color mod-left mod-bg-after-red" href="/97229/girl-kissers-vs-soar-champions-tour-north-america-stage-2-challengers-lr4">
#  <div class="match-item-time">
#  													7:45 PM											</div>
#  <div class="match-item-vs">
#  <div class="match-item-vs-team">
#  <div class="match-item-vs-team-name">
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Girl Kissers										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					0																			</div>
#  </div>
#  <div class="match-item-vs-team mod-winner">
#  <div class="match-item-vs-team-name">
#  <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											SoaR										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					2																			</div>
#  </div>
#  </div>
#  <div class="match-item-eta">
#  <div class="ml mod-completed">
#  <div class="ml-status">Completed</div>
#  <div class="ml-eta mod-completed">4d 20h</div>
#  </div>
#  </div>
#  <div class="match-item-note">
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							Stats:
#  						</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Map
#  								</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Player
#  								</div>
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							VODs:
#  						</div>
#
#
#
#
#  														Unavailable
#
#  											</div>
#  <div class="match-item-event text-of">
#  <div class="match-item-event-series text-of">
#  								Lower Round 4							</div>
#  							Open Qualifier #2											</div>
#  </a>
#  <a class="wf-module-item match-item mod-color mod-left mod-bg-after-red" href="/97228/darkzero-esports-vs-sentinels-champions-tour-north-america-stage-2-challengers-lr4">
#  <div class="match-item-time">
#  													8:05 PM											</div>
#  <div class="match-item-vs">
#  <div class="match-item-vs-team">
#  <div class="match-item-vs-team-name">
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											DarkZero Esports										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					0																			</div>
#  </div>
#  <div class="match-item-vs-team mod-winner">
#  <div class="match-item-vs-team-name">
#  <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Sentinels										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					2																			</div>
#  </div>
#  </div>
#  <div class="match-item-eta">
#  <div class="ml mod-completed">
#  <div class="ml-status">Completed</div>
#  <div class="ml-eta mod-completed">4d 20h</div>
#  </div>
#  </div>
#  <div class="match-item-note">
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							Stats:
#  						</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Map
#  								</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Player
#  								</div>
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							VODs:
#  						</div>
#
#
#
#
#  														Unavailable
#
#  											</div>
#  <div class="match-item-event text-of">
#  <div class="match-item-event-series text-of">
#  								Lower Round 4							</div>
#  							Open Qualifier #2											</div>
#  </a>
#  <a class="wf-module-item match-item mod-color mod-left mod-bg-after-red" href="/97227/nyfu-vs-ghost-gaming-champions-tour-north-america-stage-2-challengers-lr4">
#  <div class="match-item-time">
#  													8:20 PM											</div>
#  <div class="match-item-vs">
#  <div class="match-item-vs-team">
#  <div class="match-item-vs-team-name">
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											NYFU										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					1																			</div>
#  </div>
#  <div class="match-item-vs-team mod-winner">
#  <div class="match-item-vs-team-name">
#  <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Ghost Gaming										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					2																			</div>
#  </div>
#  </div>
#  <div class="match-item-eta">
#  <div class="ml mod-completed">
#  <div class="ml-status">Completed</div>
#  <div class="ml-eta mod-completed">4d 20h</div>
#  </div>
#  </div>
#  <div class="match-item-note">
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							Stats:
#  						</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Map
#  								</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Player
#  								</div>
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							VODs:
#  						</div>
#
#
#
#
#  														Unavailable
#
#  											</div>
#  <div class="match-item-event text-of">
#  <div class="match-item-event-series text-of">
#  								Lower Round 4							</div>
#  							Open Qualifier #2											</div>
#  </a>
#  </div>,
#  <div class="wf-card" style="margin-bottom: 30px;">
#  <a class="wf-module-item match-item mod-color mod-left mod-bg-after-red mod-first" href="/97230/built-by-gamers-academy-vs-ghost-gaming-champions-tour-north-america-stage-2-challengers-lr5">
#  <div class="match-item-time">
#  													3:00 PM											</div>
#  <div class="match-item-vs">
#  <div class="match-item-vs-team">
#  <div class="match-item-vs-team-name">
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Built By Gamers Academy										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					0																			</div>
#  </div>
#  <div class="match-item-vs-team mod-winner">
#  <div class="match-item-vs-team-name">
#  <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Ghost Gaming										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					2																			</div>
#  </div>
#  </div>
#  <div class="match-item-eta">
#  <div class="ml mod-completed">
#  <div class="ml-status">Completed</div>
#  <div class="ml-eta mod-completed">4d 1h</div>
#  </div>
#  </div>
#  <div class="match-item-note">
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							Stats:
#  						</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Map
#  								</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Player
#  								</div>
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							VODs:
#  						</div>
#  <div class="wf-tag mod-big mod-twitch">
#  								Twitch
#  							</div>
#  </div>
#  <div class="match-item-event text-of">
#  <div class="match-item-event-series text-of">
#  								Lower Round 5							</div>
#  							Open Qualifier #2											</div>
#  </a>
#  <a class="wf-module-item match-item mod-color mod-left mod-bg-after-red" href="/97231/sentinels-vs-soar-champions-tour-north-america-stage-2-challengers-lr5">
#  <div class="match-item-time">
#  													3:00 PM											</div>
#  <div class="match-item-vs">
#  <div class="match-item-vs-team mod-winner">
#  <div class="match-item-vs-team-name">
#  <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Sentinels										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					2																			</div>
#  </div>
#  <div class="match-item-vs-team">
#  <div class="match-item-vs-team-name">
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											SoaR										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					0																			</div>
#  </div>
#  </div>
#  <div class="match-item-eta">
#  <div class="ml mod-completed">
#  <div class="ml-status">Completed</div>
#  <div class="ml-eta mod-completed">4d 1h</div>
#  </div>
#  </div>
#  <div class="match-item-note">
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							Stats:
#  						</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Map
#  								</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Player
#  								</div>
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							VODs:
#  						</div>
#  <div class="wf-tag mod-big mod-twitch">
#  								Twitch
#  							</div>
#  </div>
#  <div class="match-item-event text-of">
#  <div class="match-item-event-series text-of">
#  								Lower Round 5							</div>
#  							Open Qualifier #2											</div>
#  </a>
#  <a class="wf-module-item match-item mod-color mod-left mod-bg-after-red" href="/97232/knights-vs-ghost-gaming-champions-tour-north-america-stage-2-challengers-lr6">
#  <div class="match-item-time">
#  													5:30 PM											</div>
#  <div class="match-item-vs">
#  <div class="match-item-vs-team">
#  <div class="match-item-vs-team-name">
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Knights										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					0																			</div>
#  </div>
#  <div class="match-item-vs-team mod-winner">
#  <div class="match-item-vs-team-name">
#  <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Ghost Gaming										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					2																			</div>
#  </div>
#  </div>
#  <div class="match-item-eta">
#  <div class="ml mod-completed">
#  <div class="ml-status">Completed</div>
#  <div class="ml-eta mod-completed">3d 23h</div>
#  </div>
#  </div>
#  <div class="match-item-note">
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							Stats:
#  						</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Map
#  								</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Player
#  								</div>
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							VODs:
#  						</div>
#  <div class="wf-tag mod-big mod-twitch">
#  								Twitch
#  							</div>
#  </div>
#  <div class="match-item-event text-of">
#  <div class="match-item-event-series text-of">
#  								Lower Round 6							</div>
#  							Open Qualifier #2											</div>
#  </a>
#  <a class="wf-module-item match-item mod-color mod-left mod-bg-after-red" href="/97233/akrew-vs-sentinels-champions-tour-north-america-stage-2-challengers-lr6">
#  <div class="match-item-time">
#  													7:55 PM											</div>
#  <div class="match-item-vs">
#  <div class="match-item-vs-team">
#  <div class="match-item-vs-team-name">
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Akrew										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					0																			</div>
#  </div>
#  <div class="match-item-vs-team mod-winner">
#  <div class="match-item-vs-team-name">
#  <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
#  <div class="text-of">
#  <span class="flag mod-us"></span>
#  											Sentinels										</div>
#  </div>
#  <div class="match-item-vs-team-score js-spoiler">
#  																					2																			</div>
#  </div>
#  </div>
#  <div class="match-item-eta">
#  <div class="ml mod-completed">
#  <div class="ml-status">Completed</div>
#  <div class="ml-eta mod-completed">3d 20h</div>
#  </div>
#  </div>
#  <div class="match-item-note">
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							Stats:
#  						</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Map
#  								</div>
#  <div class="wf-tag mod-big" style="background: #e05c65;">
#  									Player
#  								</div>
#  </div>
#  <div class="match-item-vod">
#  <div class="wf-module-label">
#  							VODs:
#  						</div>
#  <div class="wf-tag mod-big mod-twitch">
#  								Twitch
#  							</div>
#  </div>
#  <div class="match-item-event text-of">
#  <div class="match-item-event-series text-of">
#  								Lower Round 6							</div>
#  							Open Qualifier #2											</div>
#  </a>
#  </div>]

# %%
match_url_list
# Out:
# ['/96983/gorilla-gang-vs-phoenix2-champions-tour-north-america-stage-2-challengers-ro128',
#  '/96984/team-reckaroo-vs-gen-g-black-champions-tour-north-america-stage-2-challengers-ro128',
#  '/96985/t1-vs-misfits-black-champions-tour-north-america-stage-2-challengers-ro128',
#  '/96986/aftermath-esports-vs-team-opulence-gold-champions-tour-north-america-stage-2-challengers-ro128',
#  '/96987/soniqs-vs-1rule-champions-tour-north-america-stage-2-challengers-ro128',
#  '/96988/vexo-esports-vs-select-few-champions-tour-north-america-stage-2-challengers-ro128',
#  '/96991/lenny-time-vs-eros-champions-tour-north-america-stage-2-challengers-ro128',
#  '/96992/able-esports-vs-starbound-champions-tour-north-america-stage-2-challengers-ro128',
#  '/96993/gen-g-vs-panda-party-champions-tour-north-america-stage-2-challengers-ro128',
#  '/96994/spectral-esports-vs-big-baller-brand-champions-tour-north-america-stage-2-challengers-ro128',
#  '/96995/soar-vs-pasquallys-pizza-posse-champions-tour-north-america-stage-2-challengers-ro128',
#  '/96996/tradelikepros-red-vs-pulsar-red-champions-tour-north-america-stage-2-challengers-ro128',
#  '/96999/clanless-vs-slodi-repus-champions-tour-north-america-stage-2-challengers-ro128',
#  '/97000/resonate-vs-gonjo-champions-tour-north-america-stage-2-challengers-ro128',
#  '/97001/akrew-vs-ugly-hamsters-champions-tour-north-america-stage-2-challengers-ro128',
#  '/97002/nation-gaming-vs-baddiesonval-champions-tour-north-america-stage-2-challengers-ro128',
#  '/97003/team-basilisk-vs-5-of-a-kind-champions-tour-north-america-stage-2-challengers-ro128',
#  '/97004/hypehorizen-vs-zenigma-alpha-champions-tour-north-america-stage-2-challengers-ro128',
#  '/97007/nights-academy-vs-mew2-champions-tour-north-america-stage-2-challengers-ro128',
#  '/97008/unknown-vs-based-champions-tour-north-america-stage-2-challengers-ro128',
#  '/97009/complexity-vs-nanas-biscuits-champions-tour-north-america-stage-2-challengers-ro128',
#  '/97010/free-fall-vs-omnipotent-gaming-champions-tour-north-america-stage-2-challengers-ro128',
#  '/97011/cosmic-divide-vs-chapter-4-champions-tour-north-america-stage-2-challengers-ro128',
#  '/97012/lycus-empire-vs-conquest-esports-champions-tour-north-america-stage-2-challengers-ro128',
#  '/97015/skwirel-warriers-vs-shift-walkers-champions-tour-north-america-stage-2-challengers-ro128',
#  '/97016/mach5-vs-syndicates-champions-tour-north-america-stage-2-challengers-ro128',
#  '/97017/girl-kissers-vs-moonrise-black-champions-tour-north-america-stage-2-challengers-ro128',
#  '/97018/moonrise-vs-tempest-gaming-champions-tour-north-america-stage-2-challengers-ro128',
#  '/97019/nearest-airport-vs-cg-champions-tour-north-america-stage-2-challengers-ro128',
#  '/97020/new-moon-vs-rated-gaming-champions-tour-north-america-stage-2-challengers-ro128',
#  '/97023/pugstars-vs-syr-champions-tour-north-america-stage-2-challengers-ro128',
#  '/97024/solstice-esports-vs-avesta-champions-tour-north-america-stage-2-challengers-ro128',
#  '/97025/zero-marksmen-black-vs-mizzou-esports-champions-tour-north-america-stage-2-challengers-ro128',
#  '/97026/eclectiq-vs-tokyo-revengers-champions-tour-north-america-stage-2-challengers-ro128',
#  '/97027/ghost-gaming-vs-area-of-effect-champions-tour-north-america-stage-2-challengers-ro128',
#  '/97028/illuzion-vs-tbd-champions-tour-north-america-stage-2-challengers-ro128',
#  '/97031/yfp-gaming-vs-dart-monkeys-champions-tour-north-america-stage-2-challengers-ro128',
#  '/97032/swarm-esports-vs-desire-rising-champions-tour-north-america-stage-2-challengers-ro128',
#  '/97033/moon-raccoons-vs-godspeed-champions-tour-north-america-stage-2-challengers-ro128',
#  '/97034/adhd-vs-team-flux-champions-tour-north-america-stage-2-challengers-ro128',
#  '/97035/zer0-latency-vs-face-off-champions-tour-north-america-stage-2-challengers-ro128',
#  '/97036/aspyre-vs-dallas-vendetta-champions-tour-north-america-stage-2-challengers-ro128',
#  '/97039/cloud9-white-vs-ten-5-champions-tour-north-america-stage-2-challengers-ro128',
#  '/97040/oni-vs-fart-clan-champions-tour-north-america-stage-2-challengers-ro128',
#  '/97041/virtuoso-vs-nocturnals-champions-tour-north-america-stage-2-challengers-ro128',
#  '/97042/team-mystic-vs-exotic-champions-tour-north-america-stage-2-challengers-ro128',
#  '/97043/run-it-down-vs-team-opulence-black-champions-tour-north-america-stage-2-challengers-ro128',
#  '/97044/team-mystic-vs-team-blank-champions-tour-north-america-stage-2-challengers-ro128',
#  '/97046/gorilla-gang-vs-team-reckaroo-champions-tour-north-america-stage-2-challengers-ro64',
#  '/97048/soniqs-vs-vexo-esports-champions-tour-north-america-stage-2-challengers-ro64',
#  '/97050/lenny-time-vs-starbound-champions-tour-north-america-stage-2-challengers-ro64',
#  '/97051/gen-g-vs-big-baller-brand-champions-tour-north-america-stage-2-challengers-ro64',
#  '/97052/soar-vs-tradelikepros-red-champions-tour-north-america-stage-2-challengers-ro64',
#  '/97055/akrew-vs-nation-gaming-champions-tour-north-america-stage-2-challengers-ro64',
#  '/97058/nights-academy-vs-based-champions-tour-north-america-stage-2-challengers-ro64',
#  '/97059/complexity-vs-free-fall-champions-tour-north-america-stage-2-challengers-ro64',
#  '/97060/cosmic-divide-vs-lycus-empire-champions-tour-north-america-stage-2-challengers-ro64',
#  '/97063/girl-kissers-vs-moonrise-champions-tour-north-america-stage-2-challengers-ro64',
#  '/97067/zero-marksmen-black-vs-eclectiq-champions-tour-north-america-stage-2-challengers-ro64',
#  '/97068/ghost-gaming-vs-illuzion-champions-tour-north-america-stage-2-challengers-ro64',
#  '/97072/zer0-latency-vs-aspyre-champions-tour-north-america-stage-2-challengers-ro64',
#  '/97076/run-it-down-vs-team-mystic-champions-tour-north-america-stage-2-challengers-ro64',
#  '/97047/t1-vs-aftermath-esports-champions-tour-north-america-stage-2-challengers-ro64',
#  '/97075/virtuoso-vs-exotic-champions-tour-north-america-stage-2-challengers-ro64',
#  '/97056/team-basilisk-vs-hypehorizen-champions-tour-north-america-stage-2-challengers-ro64',
#  '/97066/pugstars-vs-avesta-champions-tour-north-america-stage-2-challengers-ro64',
#  '/97071/moon-raccoons-vs-adhd-champions-tour-north-america-stage-2-challengers-ro64',
#  '/97074/cloud9-white-vs-oni-champions-tour-north-america-stage-2-challengers-ro64',
#  '/97054/clanless-vs-resonate-champions-tour-north-america-stage-2-challengers-ro64',
#  '/97062/skwirel-warriers-vs-syndicates-champions-tour-north-america-stage-2-challengers-ro64',
#  '/97064/nearest-airport-vs-rated-gaming-champions-tour-north-america-stage-2-challengers-ro64',
#  '/97070/yfp-gaming-vs-desire-rising-champions-tour-north-america-stage-2-challengers-ro64',
#  '/97176/100-thieves-vs-team-reckaroo-champions-tour-north-america-stage-2-challengers-uro32',
#  '/97177/t1-vs-soniqs-champions-tour-north-america-stage-2-challengers-uro32',
#  '/97178/nyfu-vs-lenny-time-champions-tour-north-america-stage-2-challengers-uro32',
#  '/97179/gen-g-vs-soar-champions-tour-north-america-stage-2-challengers-uro32',
#  '/97180/sentinels-vs-clanless-champions-tour-north-america-stage-2-challengers-uro32',
#  '/97181/akrew-vs-team-basilisk-champions-tour-north-america-stage-2-challengers-uro32',
#  '/97182/built-by-gamers-academy-vs-nights-academy-champions-tour-north-america-stage-2-challengers-uro32',
#  '/97183/complexity-vs-cosmic-divide-champions-tour-north-america-stage-2-challengers-uro32',
#  '/97184/version1-vs-skwirel-warriers-champions-tour-north-america-stage-2-challengers-uro32',
#  '/97185/girl-kissers-vs-rated-gaming-champions-tour-north-america-stage-2-challengers-uro32',
#  '/97186/evil-geniuses-vs-pugstars-champions-tour-north-america-stage-2-challengers-uro32',
#  '/97187/zero-marksmen-black-vs-ghost-gaming-champions-tour-north-america-stage-2-challengers-uro32',
#  '/97188/knights-vs-yfp-gaming-champions-tour-north-america-stage-2-challengers-uro32',
#  '/97189/moon-raccoons-vs-aspyre-champions-tour-north-america-stage-2-challengers-uro32',
#  '/97190/darkzero-esports-vs-cloud9-white-champions-tour-north-america-stage-2-challengers-uro32',
#  '/97191/virtuoso-vs-team-mystic-champions-tour-north-america-stage-2-challengers-uro32',
#  '/97192/100-thieves-vs-soniqs-champions-tour-north-america-stage-2-challengers-uro16',
#  '/97196/version1-vs-girl-kissers-champions-tour-north-america-stage-2-challengers-uro16',
#  '/97206/t1-vs-team-reckaroo-champions-tour-north-america-stage-2-challengers-lr1',
#  '/97194/sentinels-vs-akrew-champions-tour-north-america-stage-2-challengers-uro16',
#  '/97208/team-basilisk-vs-clanless-champions-tour-north-america-stage-2-challengers-lr1',
#  '/97197/evil-geniuses-vs-ghost-gaming-champions-tour-north-america-stage-2-challengers-uro16',
#  '/97211/zero-marksmen-black-vs-pugstars-champions-tour-north-america-stage-2-challengers-lr1',
#  '/97195/built-by-gamers-academy-vs-cosmic-divide-champions-tour-north-america-stage-2-challengers-uro16',
#  '/97209/complexity-vs-nights-academy-champions-tour-north-america-stage-2-challengers-lr1',
#  '/97198/knights-vs-moon-raccoons-champions-tour-north-america-stage-2-challengers-uro16',
#  '/97212/aspyre-vs-yfp-gaming-champions-tour-north-america-stage-2-challengers-lr1',
#  '/97199/darkzero-esports-vs-virtuoso-champions-tour-north-america-stage-2-challengers-uro16',
#  '/97210/skwirel-warriers-vs-rated-gaming-champions-tour-north-america-stage-2-challengers-lr1',
#  '/97213/team-mystic-vs-cloud9-white-champions-tour-north-america-stage-2-challengers-lr1',
#  '/97193/nyfu-vs-soar-champions-tour-north-america-stage-2-challengers-uro16',
#  '/97207/gen-g-vs-lenny-time-champions-tour-north-america-stage-2-challengers-lr1',
#  '/97200/100-thieves-vs-nyfu-champions-tour-north-america-stage-2-challengers-ubqf',
#  '/97201/akrew-vs-built-by-gamers-academy-champions-tour-north-america-stage-2-challengers-ubqf',
#  '/97202/girl-kissers-vs-evil-geniuses-champions-tour-north-america-stage-2-challengers-ubqf',
#  '/97203/knights-vs-darkzero-esports-champions-tour-north-america-stage-2-challengers-ubqf',
#  '/97214/virtuoso-vs-t1-champions-tour-north-america-stage-2-challengers-lr2',
#  '/97215/moon-raccoons-vs-gen-g-champions-tour-north-america-stage-2-challengers-lr2',
#  '/97216/ghost-gaming-vs-team-basilisk-champions-tour-north-america-stage-2-challengers-lr2',
#  '/97217/version1-vs-complexity-champions-tour-north-america-stage-2-challengers-lr2',
#  '/97218/cosmic-divide-vs-skwirel-warriers-champions-tour-north-america-stage-2-challengers-lr2',
#  '/97219/sentinels-vs-pugstars-champions-tour-north-america-stage-2-challengers-lr2',
#  '/97220/soar-vs-yfp-gaming-champions-tour-north-america-stage-2-challengers-lr2',
#  '/97221/soniqs-vs-team-mystic-champions-tour-north-america-stage-2-challengers-lr2',
#  '/97225/soar-vs-soniqs-champions-tour-north-america-stage-2-challengers-lr3',
#  '/97222/virtuoso-vs-gen-g-champions-tour-north-america-stage-2-challengers-lr3',
#  '/97204/100-thieves-vs-akrew-champions-tour-north-america-stage-2-challengers-ubsf',
#  '/97224/cosmic-divide-vs-sentinels-champions-tour-north-america-stage-2-challengers-lr3',
#  '/97223/ghost-gaming-vs-complexity-champions-tour-north-america-stage-2-challengers-lr3',
#  '/97226/built-by-gamers-academy-vs-gen-g-champions-tour-north-america-stage-2-challengers-lr4',
#  '/97205/evil-geniuses-vs-knights-champions-tour-north-america-stage-2-challengers-ubsf',
#  '/97229/girl-kissers-vs-soar-champions-tour-north-america-stage-2-challengers-lr4',
#  '/97228/darkzero-esports-vs-sentinels-champions-tour-north-america-stage-2-challengers-lr4',
#  '/97227/nyfu-vs-ghost-gaming-champions-tour-north-america-stage-2-challengers-lr4',
#  '/97230/built-by-gamers-academy-vs-ghost-gaming-champions-tour-north-america-stage-2-challengers-lr5',
#  '/97231/sentinels-vs-soar-champions-tour-north-america-stage-2-challengers-lr5',
#  '/97232/knights-vs-ghost-gaming-champions-tour-north-america-stage-2-challengers-lr6',
#  '/97233/akrew-vs-sentinels-champions-tour-north-america-stage-2-challengers-lr6']

# %%
match_stats = []

for matchnum in range(len(match_url_list)):
    url = match_url_list[matchnum]
    
    source_match = requests.get(url='https://www.vlr.gg' + url).text
    
    soup_match = BeautifulSoup(source_match,'lxml')
    
    table_match = soup_match.findAll('table', {'class':'wf-table-inset mod-overview'})
    stage = soup_match.findAll('div', {'class':'match-header-event-series'})[0].text.strip().split(":", 1)[0]
    series = soup_match.findAll('div', {'class':'match-header-event-series'})[0].text.strip().split("\n", 1)[1].strip()
    
    for a in [a for a in list(range(len(table_match))) if a not in [2,3]]:
        if a in [0,1]:
            map_num = 1
        else:
            map_num = a//2
        
        map_name = soup_match.findAll('div', {'class':'vm-stats-gamesnav-item js-map-switch'})[map_num-1].text.strip()[1:].strip()
        stage = soup_match.findAll('div', {'class':'match-header-event-series'})[0].text.strip().split(":", 1)[0]
        team_name = soup_match.findAll('div', {'class':'wf-title-med'})[a % 2].text.strip()
        
        table = table_match[a]
        headers_match = []
        
        for i in table.find_all('th'):
            title_match = i.text.strip()
            headers_match.append(title_match)
            
        headers_match[0] = 'Player Name'
        headers_match[1] = 'Agent Name'
        headers_match[6] = 'K/D +/–'   
        headers_match[12] = 'FK/FD +/–'   
        df_match = pd.DataFrame(columns=headers_match)
        
        for row in table.find_all('tr')[1:]:
            data = row.find_all('td')
            row_data = [td.text.strip() for td in data]
            row_data[1] = str(data[1]).split('title="',1)[1].split('"',1)[0].title()
            length = len(df_match)
            df_match.loc[length] = row_data
        
        df_match['Team Name'] = team_name
        df_match['Map Name'] = map_name
        df_match['Map #'] = map_num
        df_match['Stage'] = stage
        df_match['Series'] = series
        
        match_stats.append(df_match)

# %%
result = pd.concat(match_stats).reset_index(drop=True)
result['Player Name'] = result['Player Name'].str.split("\n", 1).str[0].str.strip()
result['D'] = result['D'].str[1:-1]
result = result.apply(pd.to_numeric, errors='ignore')
result.drop('KAST', axis=1, inplace = True)

# %%
result
# Out:
#     Player Name Agent Name  ACS   K   D  A  K/D +/–  ADR  HS%  FK  FD  \
# 0          stax     Breach  262  22  11  5       11  157  53%   2   2
# 1            Rb       Skye  212  13  10  7        3  158  33%   4   2
# 2          k1Ng    Killjoy  212  13  13  3        0  158  24%   3   2
# 3          MaKo      Astra  209  13   8  6        5  154  24%   1   1
# 4          BuZz       Jett  206  14  12  6        2  152  38%   0   1
# ..          ...        ...  ...  ..  .. ..      ...  ...  ...  ..  ..
# 705       d3ffo       Jett  271  19  18  1        1  176  29%   5   5
# 706   Chronicle    Killjoy  212  14  15  3       -1  144  19%   2   2
# 707        nAts      Viper  169  12  16  4       -4  111  18%   0   2
# 708      Redgar      Astra  125   9  17  5       -8  102  20%   0   3
# 709     sheydos       Skye  110   9  16  4       -7   79  21%   1   1
#
#      FK/FD +/–        Team Name Map Name  Map #        Stage       Series
# 0            0  Vision Strikers    Haven      1  Group Stage  Opening (D)
# 1            2  Vision Strikers    Haven      1  Group Stage  Opening (D)
# 2            1  Vision Strikers    Haven      1  Group Stage  Opening (D)
# 3            0  Vision Strikers    Haven      1  Group Stage  Opening (D)
# 4           -1  Vision Strikers    Haven      1  Group Stage  Opening (D)
# ..         ...              ...      ...    ...          ...          ...
# 705          0   Gambit Esports    Split      5     Playoffs  Grand Final
# 706          0   Gambit Esports    Split      5     Playoffs  Grand Final
# 707         -2   Gambit Esports    Split      5     Playoffs  Grand Final
# 708         -3   Gambit Esports    Split      5     Playoffs  Grand Final
# 709          0   Gambit Esports    Split      5     Playoffs  Grand Final
#
# [710 rows x 17 columns]

# %%
result[result['Player Name'] == 'TenZ']
# Out:
#     Player Name Agent Name  ACS   K   D  A  K/D +/–  ADR  HS%  FK  FD  \
# 101        TenZ       Jett  262  21  16  5        5  179  18%   4   3
# 110        TenZ       Jett  270  22  17  3        5  171  30%   5   2
# 120        TenZ       Jett  267  22  16  3        6  166  16%   5   0
# 238        TenZ       Jett  163  14  21  4       -7  110  19%   6   4
# 245        TenZ       Jett  369  21   6  2       15  211  19%   5   2
# 258        TenZ       Jett  141  12  20  2       -8  102  18%   4   5
# 402        TenZ       Jett  202  13  12  6        1  136  18%   5   5
# 411        TenZ       Jett  234  18  15  6        3  163  17%   5   1
# 424        TenZ       Jett  119   9  20  7      -11   92  24%   1   7
#
#      FK/FD +/–  Team Name  Map Name  Map #        Stage        Series
# 101          1  Sentinels    Ascent      1  Group Stage   Opening (B)
# 110          3  Sentinels    Breeze      2  Group Stage   Opening (B)
# 120          5  Sentinels     Haven      3  Group Stage   Opening (B)
# 238          2  Sentinels    Breeze      1  Group Stage  Winner's (B)
# 245          3  Sentinels      Bind      2  Group Stage  Winner's (B)
# 258         -1  Sentinels     Split      3  Group Stage  Winner's (B)
# 402          0  Sentinels  Fracture      1  Group Stage   Decider (B)
# 411          4  Sentinels     Haven      2  Group Stage   Decider (B)
# 424         -6  Sentinels     Split      3  Group Stage   Decider (B)

# %%
result[result['Agent Name'] == 'Jett'].groupby(['Player Name']).mean().sort_values('ACS', ascending=False)
# Out:
#                     ACS          K          D         A    K/D +/–  \
# Player Name
# Derke        305.500000  26.500000  14.750000  1.750000  11.750000
# leaf         299.800000  24.000000  18.000000  6.800000   6.000000
# heat         264.800000  17.600000  14.400000  1.600000   3.200000
# Sushiboys    250.500000  20.000000  12.500000  3.000000   7.500000
# yay          242.714286  18.857143  15.285714  3.142857   3.571429
# DubsteP      237.666667  15.666667  13.666667  2.000000   2.000000
# cNed         231.454545  16.636364  14.727273  3.909091   1.909091
# xand         231.166667  17.666667  17.166667  3.833333   0.500000
# Patiphan     230.285714  16.428571  15.142857  4.142857   1.285714
# PTC          227.000000  19.000000  17.000000  8.000000   2.000000
# BuZz         226.571429  16.285714  15.428571  3.142857   0.857143
# d3ffo        225.357143  16.428571  15.285714  2.857143   1.142857
# TenZ         225.222222  16.888889  15.888889  4.222222   1.000000
# Jamppi       212.000000  16.500000  17.500000  2.500000  -1.000000
# Fisker       206.500000  13.750000  16.750000  2.500000  -3.000000
# JohnOlsen    203.000000  12.333333  16.666667  4.666667  -4.333333
# NagZ         197.846154  15.230769  14.384615  3.000000   0.846154
# gtnJESUS     194.600000  15.400000  14.800000  3.000000   0.600000
# ScreaM       164.666667  11.333333  13.666667  3.000000  -2.333333
#
#                     ADR        FK        FD  FK/FD +/–     Map #
# Player Name
# Derke        186.750000  6.500000  3.750000   2.750000  1.250000
# leaf         197.000000  7.000000  4.200000   2.800000  1.800000
# heat         174.800000  2.600000  3.200000  -0.600000  1.800000
# Sushiboys    168.500000  2.500000  1.000000   1.500000  1.000000
# yay          159.857143  4.285714  2.571429   1.714286  1.714286
# DubsteP      153.444444  4.000000  2.555556   1.444444  1.666667
# cNed         153.454545  3.636364  2.454545   1.181818  2.272727
# xand         145.666667  3.666667  3.500000   0.166667  2.000000
# Patiphan     147.857143  3.571429  2.714286   0.857143  2.000000
# PTC          159.000000  7.000000  6.000000   1.000000  2.000000
# BuZz         143.142857  2.857143  3.142857  -0.285714  1.857143
# d3ffo        145.071429  4.571429  3.214286   1.357143  2.357143
# TenZ         147.777778  4.444444  3.222222   1.222222  2.000000
# Jamppi       122.500000  4.000000  4.500000  -0.500000  2.000000
# Fisker       127.500000  2.250000  4.750000  -2.500000  1.500000
# JohnOlsen    145.333333  3.333333  4.666667  -1.333333  1.333333
# NagZ         126.923077  3.692308  3.461538   0.230769  1.846154
# gtnJESUS     119.800000  2.600000  3.000000  -0.400000  1.800000
# ScreaM       114.333333  0.666667  3.666667  -3.000000  1.333333
